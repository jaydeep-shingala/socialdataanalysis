# %% [markdown]
# # Extracting users data from facebook developer API

# %% [markdown]
# ## importing needed libraries

# %%
import cred
from facebook_scraper import *
import pandas as pd

df1 = get_profile("raj.bhuva.336")
df1
# Out:
# {'cover_photo_text': None,
#  'cover_photo': 'https://scontent.fstv4-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/53397816_1142634675943911_6363350896381788160_n.jpg?_nc_cat=111&ccb=1-5&_nc_sid=85a577&efg=eyJpIjoidCJ9&_nc_ohc=JsTAnM23sqgAX-6EL0_&_nc_ht=scontent.fstv4-1.fna&oh=76a79436be4d1dfdcae841a64f151837&oe=6178767A&manual_redirect=1',
#  'profile_picture': 'https://scontent.fstv4-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/53397816_1142634675943911_6363350896381788160_n.jpg?_nc_cat=111&ccb=1-5&_nc_sid=85a577&efg=eyJpIjoidCJ9&_nc_ohc=JsTAnM23sqgAX-6EL0_&_nc_ht=scontent.fstv4-1.fna&oh=76a79436be4d1dfdcae841a64f151837&oe=6178767A&manual_redirect=1',
#  'id': '100005921674574',
#  'Name': 'Raj Bhuva',
#  'Education': 'shree swami atmanand saraswati institute of Technology\nUniversity\nAshaDeep Science & comerce Bhavan\nHigh School',
#  'Places lived': [{'link': '/profile.php?id=114669868550573',
#    'text': 'Surat, Gujarat',
#    'type': 'Current town/city'},
# ...

# %% [markdown]
# ## generating data set out of extracted data

# %%
df = pd.DataFrame.from_dict(df1,orient ='index',columns=None)

df =  df.drop(['profile_picture','id'])
print(df)
# Out:
#                                                                   0
# cover_photo_text                                               None
# cover_photo       https://scontent.fstv4-1.fna.fbcdn.net/v/t1.64...
# Name                                                      Raj Bhuva
# Education         shree swami atmanand saraswati institute of Te...
# Places lived      [{'link': '/profile.php?id=114669868550573', '...
# Contact Info      {'Facebook': '/raj.bhuva.336', 'Instagram': 'r...
# Basic info        {'Gender': 'Male', 'Languages': 'Gujarati (Ind...
# Relationship                                                 Single
# Family members                                 Pravin Bhuva\nFather
# Life events

# %%
df11 = []
for post in get_posts('raj.bhuva.336', pages=1,credentials = (cred.cred['hellorohanpatel@gmail.com'],cred.cred['hello@hello'])):
    df11.append(post)

# %%
dfnew = pd.DataFrame(df11)
dfnew
# Out:
#             post_id                                      text  \
# 0  1142634672610578
# 1   737598339780882
# 2   604814183059299
# 3   564883603719024
# 4   561807380693313
# 5   557501891123862
# 6   556406691233382
# 7   505607956313256
# 8   489027904637928  Created using fb.com/supportdigitalindia
# 9   444921149048604
#
#                                   post_text shared_text                time  \
# 0                                                  None 2019-03-08 22:55:00
# 1                                                  None 2017-04-22 15:39:00
# 2                                                  None 2016-08-08 21:16:00
# 3                                                  None 2016-04-29 12:52:00
# 4                                                  None 2016-04-21 13:40:00
# 5                                                  None 2016-04-09 09:55:00
# 6                                                  None 2016-04-06 16:46:00
# ...

# %% [markdown]
# # using Regular Expression for geneating usefull insights

# %%
import re
def cleanTxt(text):
    text = re.sub('@[A-Za-z0–9]+', '', text) #Removing @mentions
    text = re.sub('#', '', text) # Removing '#' hash tag
    text = re.sub('RT[\s]+', '', text) # Removing RT
    text = re.sub('https?:\/\/\S+', '', text) # Removing hyperlink
 
    return text
df[0] = df[0].apply(cleanTxt)
df.dropna()
df
# Out:
#                                                                             0
# Name                                                                Raj Bhuva
# શિક્ષણ                      shree swami atmanand saraswati institute of Te...
# નિવાસ કર્યો હોય તેવા સ્થળો                   સુરત\nવર્તમાન શહેર\nસુરત\nમૂળવતન
